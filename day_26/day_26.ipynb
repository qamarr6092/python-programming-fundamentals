# %%
#format specifer
a  = 232.2321
print ( f'{a:.2f}')
#: start of a format specifier
#.2 2 decimal points , f means floating numbers
print(f'{a:,}')
# Out:
# 232.23
# 232.2321

# %%
from datetime import datetime , date , time
dt = datetime(1993 , 10 , 27 )
print (dt.day)
print(dt.date())

dt.time()
dt.strftime('%Y-%m-%d')
#this returns the string
# Out:
# 27
# 1993-10-27
# '1993-10-27'

# %%
datetime.strptime('10-1-2026' , '%d-%m-%Y')
#converts string into datetime instance
# Out:
# datetime.datetime(2026, 1, 10, 0, 0)

# %%
tup = 4 , 5 ,6
tup
tup2=  (1 , 2 ,3)
print(tup2)
# Out:
# (1, 2, 3)

# %%
#we can convert any iterator to tuple using tuple method
a= { 'name' : 'qamar' }
b = tuple ( a.items())
x  = tuple ( [ 1 , 565 ,3])
print(x)
print(b)
name =  tuple ( 'qamar')
print ( name )
# Out:
# (1, 565, 3)
# (('name', 'qamar'),)
# ('q', 'a', 'm', 'a', 'r')

# %%
nested_tup = (1,23,3 ) , (5, 6,8) , ( 12, 12,(1,))
print(nested_tup)
tup = 1 , 2, 3
print ( tup)
#Commas create the tuple
# Out:
# ((1, 23, 3), (5, 6, 8), (12, 12, (1,)))
# (1, 2, 3)

# %%
t = tuple ( [1, 'qamar' , [1,23,1] ] )
print (t)
t + (1,), (23,)     #see! it is commas who created the tuples not the parenthesis
# Out:
# (1, 'qamar', [1, 23, 1])
# ((1, 'qamar', [1, 23, 1], 1), (23,))

# %%
tup = ( 1, 2 ,('a' , ('c', )))
a,b,(c,d) = tup
print(a,b,c,d)
a,b,(c,(d,)) = tup
print ( a, b , c,d)
# Out:
# 1 2 a ('c',)
# 1 2 a c

# %%
#Swapping variables
a = 3
b = 2
b , a = a,b
print(a,b)
tup = a,b
tup
#Swapping is done here as a goes to b and b goes to a so the values are swapped!
# Out:
# 2 3
# (2, 3)

# %%
a,b = [1,2] , [1]
print ( a,b)
seq = [(1 ,2 ,3 ) ,(4,5,6) ]
for a , b ,c in seq :
    print(f'a={a} , b={b} , c={c} ')
# Out:
# [1, 2] [1]
# a=1 , b=2 , c=3
# a=4 , b=5 , c=6

# %%
a , b,*c = 1,2,3,4,5,6,7,8,9
print(a,b,c)
#The remaining values are stored in the last variable as a list
#Typically used as inwanted values
# Out:
# 1 2 [3, 4, 5, 6, 7, 8, 9]

# %%
tup = 1, 2 ,3 ,5
lst = list(tup)
print(lst)
#This is called data structure conversion
#Setting back to tuple
tp = tuple(lst)
print(tp)
lst2  = list(tp)
lst2.append('qamar')
print(lst)
print(lst2)
#Each conversion creates different object so their references are different even if their values are same
# Out:
# [1, 2, 3, 5]
# (1, 2, 3, 5)
# [1, 2, 3, 5]
# [1, 2, 3, 5, 'qamar']

# %%
lst.insert(1,'k')
lst
# Out:
# [1, 'k', 2, 3, 5]

# %%
lst.clear()
lst.extend([1,2,3])
print(lst)
lst.append([1,2,3])
lst
#See the difference between the extend() and append () method
#And extend () works better than list + list
# Out:
# [1, 2, 3]
# [1, 2, 3, [1, 2, 3]]

# %%
info = { 'name' : 'Qamar' ,
         'class' : 'Second Year' ,
         'birth_date' : '2-10-2006'
       }
print(info)
del info ['class']
print(info)
name = info.pop('name')
info
info.update( name  = name )
info.update( { 'batch' : 2024 } )
print(info)
info.update( [ ( 'food' , 'pizza') ] )
print ( info )

#So the update method works with only **kwargs, list of tuples of k,v pair and another dictionary such
#as { .... }
# Out:
# {'name': 'Qamar', 'class': 'Second Year', 'birth_date': '2-10-2006'}
# {'name': 'Qamar', 'birth_date': '2-10-2006'}
# {'birth_date': '2-10-2006', 'name': 'Qamar', 'batch': 2024}
# {'birth_date': '2-10-2006', 'name': 'Qamar', 'batch': 2024, 'food': 'pizza'}

# %%
#Zip method
# zip “pairs” up the elements of a number of lists, tuples, or other sequences to create a
# list of tuples:
a= [ 1 , 2 ]
b = ['a' , 'b']
z=  list(zip ( a ,b ))
print(z)
print(list(z))
d = dict ( z )
print ( d)
# Out:
# [(1, 'a'), (2, 'b')]
# [(1, 'a'), (2, 'b')]
# {1: 'a', 2: 'b'}

# %%
#sets
a = set ( [ 1 , 2 , 3 ] )
print ( a )
b = set ( { 1 : 'a' , 2 : 'b' }.items() )
print ( b)
# Out:
# {1, 2, 3}
# {(2, 'b'), (1, 'a')}

# %%
a = { 1 ,2 , 3 }
b =   { 1 ,4 ,2 ,9 }
print(a.union(b) )

a.intersection ( b )
# a.union(b) a | b All of the unique elements in a and b
# a.update(b) a |= b Set the contents of a to be the union of the elements
# in a and b
# a.intersection(b) a & b All of the elements in both a and b
# a.intersection_update(b) a &= b Set the contents of a to be the intersection of the
# elements in a and b
# a.difference(b) a - b The elements in a that are not in b
# a.difference_update(b) a -= b Set a to the elements in a that are not in b
# a.symmetric_difference(b) a ^ b All of the elements in either a or b but not both
# a.symmetric_difference_update(b) a ^= b Set a to contain the elements in either a or b but
# not both
# a.issubset(b) <= True if the elements of a are all contained in b
# a.issuperset(b) >= True if the elements of b are all contained in a
# a.isdisjoint(b) N/A True if a and b have no elements in common
# a.add(x) N/A Add element x to set a
# a.clear() N/A Reset set a to an empty state, discarding all of its
# elements
# a.remove(x) N/A Remove element x from set a
# a.pop() N/A Remove an arbitrary element from set a, raising
# KeyError if the set is empty
# Out:
# {1, 2, 3, 4, 9}
# {1, 2}
